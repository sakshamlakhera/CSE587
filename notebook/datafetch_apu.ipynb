# %% [markdown]
# Hi, here I, Apurva, will be working my own hypothesis and fetch my own datasets, which will later be merged with main project.
#
# Hypothesis #1: Does exposure to certain chemicals in early childhood cause ADHD?

# %%
import pandas as pd 

url1 = r"https://pasteur.epa.gov/uploads/10.23719/1504060/Childhood%20Chemical%20Exposures%20ADHD_SciHub.xlsx"

chem_adhd_dat = pd.read_excel(url1)
